# %% [markdown]
# # Part 6: **Build an Interactive Dashboard with Ploty Dash**

# %%
import pandas as pd
import dash
from dash import html, dcc, Input, Output, State

import plotly.express as px

# %%
# Read the airline data into pandas dataframe

spacex_df = pd.read_csv("spacex_launch_dash.csv")

spacex_df.drop(['Unnamed: 0'], axis=1, inplace=True)


max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

spacex_df.head()
# Out:
#    Flight Number  Launch Site  class  Payload Mass (kg) Booster Version  \
# 0              1  CCAFS LC-40      0                0.0  F9 v1.0  B0003
# 1              2  CCAFS LC-40      0                0.0  F9 v1.0  B0004
# 2              3  CCAFS LC-40      0              525.0  F9 v1.0  B0005
# 3              4  CCAFS LC-40      0              500.0  F9 v1.0  B0006
# 4              5  CCAFS LC-40      0              677.0  F9 v1.0  B0007
#
#   Booster Version Category
# 0                     v1.0
# 1                     v1.0
# 2                     v1.0
# 3                     v1.0
# 4                     v1.0

# %%
sites_list=list(set(spacex_df['Launch Site']))
sites_list.append('All Sites')
sites_list
# Out:
# ['KSC LC-39A', 'CCAFS LC-40', 'VAFB SLC-4E', 'CCAFS SLC-40', 'All Sites']

# %%
#total_success=spacex_df[spacex_df['class']==1]
#total_success_df=total_success[['Flight Number','Launch Site', 'class']]
#total_success_df.head()

# %%
#total_df=spacex_df[['Launch Site', 'class']]
#total_df.head()

# %%
# Create a dash application
app = dash.Dash(__name__)

# Create an app layout

sites=sites_list



app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center',
                                               'color': '#503D34',
                                               'font-size': 35}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                dcc.Dropdown(
                                   id='site-dropdown',
                                   options=[
                                    {'label': i, 'value': i} for i in sites],
                                    placeholder="Select a Launch Site here",
                                    value='All Sites',
                                    searchable=True),
                            
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                dcc.RangeSlider(id='payload-slider',
                                min=0, max=10000, step=1000,
                                value=[min_payload,max_payload],
                                marks={
                                0: '0 kg',
                                2500: '2500',
                                5000: '5000',
                                7500: '7500',
                                10000: '10000'
                                }),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(
Output(component_id='success-pie-chart', component_property='figure'),
Input(component_id='site-dropdown', component_property='value')
)
def get_pie(value):
    filtered_df = spacex_df
    if value == 'All Sites':
        fig = px.pie(filtered_df, values='class', names='Launch Site', title='Total Success Launches By Site')
        return fig

    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == value].groupby(['Launch Site', 'class']). \
        size().reset_index(name='class count')
        title = f"Total Success Launches for site {value}"
        fig = px.pie(filtered_df,values='class count', names='class', title=title)
        return fig

# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(
Output(component_id='success-payload-scatter-chart', component_property='figure'),
[Input(component_id='site-dropdown', component_property='value'),
Input(component_id='payload-slider', component_property='value')]
)

def get_scatter(value1,value2):
    filtered_df2_1=spacex_df[(spacex_df['Payload Mass (kg)'] > value2[0]) & (spacex_df['Payload Mass (kg)'] < value2[1])]

    if value1=='All Sites':
        fig= px.scatter(filtered_df2_1,x="Payload Mass (kg)",y="class",color="Booster Version Category",\
        title="Correlation between Payload and Success for All sites")
        return fig
    else :
        filtered_df2_2=filtered_df2_1[filtered_df2_1['Launch Site']==value1]
        fig= px.scatter(filtered_df2_2,x="Payload Mass (kg)",y="class",color="Booster Version Category",\
        title=f"Correlation between Payload and Success for site {value1}")
        return fig
# Run the app
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [18/Aug/2022 16:19:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:19:03] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:19:03] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:19:03] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Aug/2022 16:19:03] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Aug/2022 16:19:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:19:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:19:03] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Aug/2022 16:19:04] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [18/Aug/2022 16:21:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:21:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:21:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:21:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:21:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:22:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:24:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:24:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:24:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:24:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:24:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:24:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:24:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:24:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:25:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:25:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:25:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:25:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:25:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:25:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:25:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:25:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:25:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:25:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:28:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:28:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Aug/2022 16:28:44] "POST /_dash-update-component HTTP/1.1" 200 -
